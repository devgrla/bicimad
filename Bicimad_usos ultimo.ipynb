# %% [markdown]
#    # TRATAMIENTO Y ANÁLISIS DE BASE DE DATOS "USOS BICIMAD"
#
# La base **'Bicis acumulados por día'** nos da la información desde junio de 2014 hasta diciembre de 2018. Nos entrega columnas con información de fechas, *tipo de abonado*, y *cantidad de uso por abonado*. Inicialmente la idea es identificar como es el comportamiento de cada tipo de abonado por año, por mes y por día de semana. Anes de esto deberemos transformar la tabla y adaptarla a nuestras necesidades.

# %% [markdown]
# ## Librerías a importar
#
# Realizamos las importaciones de las librerías que se van a utilizar. En este caso vamos a trabajar inicialmente con:
#
#     * Pandas
#     * Pandasplot
#     * Numpy
#     * Seaborn
#     * Matplotlib
#
#  Estas librearías nos permitirán en su orden la manipulación de los datos y su posterior graficación.

# %%
from datetime import date, datetime
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt 

from matplotlib import rcParams

rcParams['figure.figsize'] = 14, 10
sns.set_context('talk') #Ampliación de gráficas

# %% [markdown]
# ## Extracción de los datos
# El fichero *'bicis_usos_acumulado'* se encuentra enformato CSV por lo cual se se realizará la extracción con pandas read_csv.

# %%
bicis_usos = pd.read_csv('TFM/bicis_usos_acumulado por dia.csv', sep=';', index_col=False)

# %% [markdown]
# ## Inspección de datos
#
# En este punto revisamos el tipo de datos que tenemos, el temaño de la tabla, cantidad de columnas y filas.

# %% [markdown]
# Visualizamos las primeras 5 columnas y filas de la tabla. La columna index por defecto iniciará desde 'cero'.

# %%
bicis_usos.head()
# Out:
#           DIA  Usos bicis abono anual   Usos bicis abono ocasional   \
# 0  23/06/2014                       17                           79
# 1  24/06/2014                       24                           48
# 2  25/06/2014                      105                           14
# 3  26/06/2014                      120                           15
# 4  27/06/2014                      131                           18
#
#    Usos bicis total  Usos abono anual acumulado  \
# 0                96                          17
# 1                72                          41
# 2               119                         146
# 3               135                         266
# 4               149                         397
#
#    Usos abono ocasional acumulado  Usos total acumulado desde inicio  \
# 0                              79                                 96
# 1                             127                                168
# 2                             141                                287
# 3                             156                                422
# 4                             174                                571
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# Visualizamos las últimas 5 columnas y filas de la tabla.

# %%
bicis_usos.tail()
# Out:
#              DIA  Usos bicis abono anual   Usos bicis abono ocasional   \
# 1648  27/12/2018                     7282                          151
# 1649  28/12/2018                     7386                          256
# 1650  29/12/2018                     5584                          250
# 1651  30/12/2018                     5114                          301
# 1652  31/12/2018                     4718                          283
#
#       Usos bicis total  Usos abono anual acumulado  \
# 1648              7433                    13248202
# 1649              7642                    13255588
# 1650              5834                    13261172
# 1651              5415                    13266286
# 1652              5001                    13271004
#
#       Usos abono ocasional acumulado  Usos total acumulado desde inicio  \
# 1648                          279743                           13527945
# 1649                          279999                           13535587
# 1650                          280249                           13541421
# 1651                          280550                           13546836
# 1652                          280833                           13551837
#
#       Unnamed: 7
# 1648         NaN
# 1649         NaN
# 1650         NaN
# 1651         NaN
# 1652         NaN

# %% [markdown]
# Revisamos los diferentes tipos de datos con los que contamos, ya advertimos que la columna DIA precisa conversión a formato
# fecha. Los demás datos tal cual como se encuentran nos servirán.

# %%
bicis_usos.dtypes
# Out:
# DIA                                   object
# Usos bicis abono anual                 int64
# Usos bicis abono ocasional             int64
# Usos bicis total                       int64
# Usos abono anual acumulado             int64
# Usos abono ocasional acumulado         int64
# Usos total acumulado desde inicio      int64
# Unnamed: 7                           float64
# dtype: object

# %% [markdown]
# Revisamos demás dimensiones para obtener la cantidad de filas y columnas.

# %%
bicis_usos.shape
# Out:
# (1653, 8)

# %% [markdown]
# Implementamos **.describe** para obtener la información relacionada con la distribución de los *datos, count, mean,std*.

# %%
bicis_usos.describe()
# Out:
#        Usos bicis abono anual   Usos bicis abono ocasional   Usos bicis total  \
# count              1653.000000                  1653.000000       1653.000000
# mean               8028.435572                   169.892922       8198.328494
# std                3254.682257                   138.050983       3299.990485
# min                  17.000000                     0.000000         72.000000
# 25%                5413.000000                    61.000000       5525.000000
# 50%                8067.000000                   148.000000       8306.000000
# 75%               10361.000000                   235.000000      10567.000000
# max               16529.000000                   745.000000      16732.000000
#
#        Usos abono anual acumulado  Usos abono ocasional acumulado  \
# count                1.653000e+03                     1653.000000
# mean                 5.919122e+06                   126483.773745
# std                  3.950482e+06                    88504.447352
# min                  1.700000e+01                       79.000000
# 25%                  2.290500e+06                    46187.000000
# 50%                  5.991439e+06                   131358.000000
# 75%                  9.357290e+06                   208761.000000
# max                  1.327100e+07                   280833.000000
#
#        Usos total acumulado desde inicio  Unnamed: 7
# count                       1.653000e+03         0.0
# mean                        6.045606e+06         NaN
# std                         4.038907e+06         NaN
# min                         9.600000e+01         NaN
# 25%                         2.336687e+06         NaN
# 50%                         6.122797e+06         NaN
# 75%                         9.566051e+06         NaN
# max                         1.355184e+07         NaN

# %% [markdown]
# ## Transformación de los datos
#
# La etapa de transformación de datos incluye:
#
# * Cambio de etiquetas
# * Transformación de tipo de datos
# * Eliminación de columnas sin importancia
# * Generación de nuevas columnas formuladas

# %% [markdown]
# Cambiamos los nombres de todas las columnas por nombre mas entendibles y/o faciles de manejar

# %%
bicis_usos.columns=['fecha', 'abono_anual', 'abono_ocasional', 'total_abonos', 'a_a_acum', 'a_o_acum', 'total_acum', 'na']
bicis_usos.head()
# Out:
#         fecha  abono_anual  abono_ocasional  total_abonos  a_a_acum  a_o_acum  \
# 0  23/06/2014           17               79            96        17        79
# 1  24/06/2014           24               48            72        41       127
# 2  25/06/2014          105               14           119       146       141
# 3  26/06/2014          120               15           135       266       156
# 4  27/06/2014          131               18           149       397       174
#
#    total_acum  na
# 0          96 NaN
# 1         168 NaN
# 2         287 NaN
# 3         422 NaN
# 4         571 NaN

# %% [markdown]
# ### Cambio de formato de fecha
#
# En este caso se aplicará una función apply para modificar la columna fecha la cual por defecto está en formato Objet, y la necesitamos en 'datetime'.

# %%
def cast_date(date):
    return datetime.strptime(date, '%d/%m/%Y')

bicis_usos['fecha'] = bicis_usos.fecha.apply(cast_date)

# %% [markdown]
# Ahora queda en formato **Datetime**.

# %%
bicis_usos.dtypes
# Out:
# fecha              datetime64[ns]
# abono_anual                 int64
# abono_ocasional             int64
# total_abonos                int64
# a_a_acum                    int64
# a_o_acum                    int64
# total_acum                  int64
# na                        float64
# dtype: object

# %% [markdown]
# ### Eliminación de columna
#
# Usamos la función .Drop para eliminar las columnas que a nuestro modo de ver no aportan nada a nuestros intereses.

# %%
bicis_usos.head(1)
# Out:
#        fecha  abono_anual  abono_ocasional  total_abonos  a_a_acum  a_o_acum  \
# 0 2014-06-23           17               79            96        17        79
#
#    total_acum  na
# 0          96 NaN

# %%
bicis_usos.drop(bicis_usos.columns[[4,5,6,7]], axis=1, inplace=True)

# %% [markdown]
# Confirmamos eliminación de columna.

# %%
bicis_usos.head(1)
# Out:
#        fecha  abono_anual  abono_ocasional  total_abonos
# 0 2014-06-23           17               79            96

# %% [markdown]
# ### Creación de nuevas columnas
#
# A partir de la columna fecha vamos a extraer una columna con el 'año' y otra con el 'mes'. Adicionalmente vamos a generar una
# función que nos cree una columna con el día de la semana. En ambos casos usaremos 'apply' con la función lambda.

# %% [markdown]
# Para mejor tratamiento de los datos generamos dos columnas nuevas:'ano' y 'mes' con lambda.

# %%
bicis_usos['ano'] = bicis_usos.apply(lambda fila: fila.fecha.year, axis = 1)
bicis_usos['mes'] = bicis_usos.apply(lambda fila: fila.fecha.month, axis = 1)

# %% [markdown]
# Es necesario identificar los días de la semana, por lo que incorporamos la función 'get_day_of_week' en linea con apply.
# En el mismo proceso creamos una nueva columna la cual llamaremos *'dia_semana'*.

# %%
def get_day_of_week(row):    
    day = row.fecha.weekday()
    if day == 0:
        return 'Lunes'
    elif day == 1:
        return 'Martes'
    elif day == 2:
        return 'Miércoles'
    elif day == 3:
        return 'Jueves'
    elif day == 4:
        return 'Viernes'
    elif day == 5:
        return 'Sabádo'
    elif day == 6:
        return 'Domingo'
    
bicis_usos['dia_semana'] = bicis_usos.apply( get_day_of_week, axis = 1)
    
bicis_usos.head()
# Out:
#        fecha  abono_anual  abono_ocasional  total_abonos   ano  mes dia_semana
# 0 2014-06-23           17               79            96  2014    6      Lunes
# 1 2014-06-24           24               48            72  2014    6     Martes
# 2 2014-06-25          105               14           119  2014    6  Miércoles
# 3 2014-06-26          120               15           135  2014    6     Jueves
# 4 2014-06-27          131               18           149  2014    6    Viernes

# %% [markdown]
# Con el fin de obtener un vista de los datos que nos permita generar otras opciones de gráficas y análisis,
# aplicamos la función MELT
#
# Reasignamos nombres nuevamente a las columnas de la nueva versión de la tabla.

# %%
bicis_usos_melt = pd.melt(bicis_usos, id_vars=["ano", "mes", "dia_semana"], value_vars=['abono_anual', 'abono_ocasional'], )
bicis_usos_melt.columns = ['ano', 'mes', 'dia_semana', 'tipo_usuario', 'cantidad_usos']
bicis_usos_melt.head(5)
# Out:
#     ano  mes dia_semana tipo_usuario  cantidad_usos
# 0  2014    6      Lunes  abono_anual             17
# 1  2014    6     Martes  abono_anual             24
# 2  2014    6  Miércoles  abono_anual            105
# 3  2014    6     Jueves  abono_anual            120
# 4  2014    6    Viernes  abono_anual            131

# %% [markdown]
# ## Gráficas

# %%
# %matplotlib inline

# %% [markdown]
# Los datos obtenidos cuentan con pocas variables categóricas, razón por la cual optamos inicialmente por mostrar dos gráficas que contienen el nivel de uso de los tipos de usuarios como lo es el *Usuario de abono anual* y el *Usuario de abono ocasional*, que además manejan frecuencias de usos muy distintas, por lo tanto es mejor trabajar cada tipo de usuario por separado para poder visualizar a mejor escala los comportamientos de cada uno.

# %% [markdown]
# Con esta gráfica tipo **lineplot** podemos ver por separado las diferencias de escala en los desempeños por año de cada tipo de usuario.

# %%
out = sns.lineplot(data=bicis_usos_melt, x='ano', y='cantidad_usos', hue='tipo_usuario')

# %% [markdown]
# Otra vision con Catplot retratanto la diferencia de escalas de cada tipo de usuario pero en una sola gráfica.

# %%
sns.set(style="ticks")
sns.catplot(x="ano", y="cantidad_usos", hue="tipo_usuario", data=bicis_usos_melt)

# %% [markdown]
# ****GRAFICAS DE ESCALA ANUAL****

# %% [markdown]
# Con esta gráfica **Boxplot** por *Uso Total* observamos la relación de la variable de **'usos'** con la variable **'año'**. En otras palabras como el sistema aumenta anualmente su nivel de demanda. En junio de 2014 se inician actividades y rápidamente pasa de 7.000 usos aproximadamente a 15.000 usos en 2015. En 2016 se presenta una disminución* y en los próximos años retoma nuevamente la senda creciente. Podemos observar también que no se presentan datos átipicos importantes y además como en el 3er cuartil se van concentrando para los últimos 2 años una demanda de 8000 a 11000 usos por año.

# %% [markdown]
# * En 2016 se presenta la municipalización del sistema, que en su transición deja por fuera por concepto de mantenimiento mas de 1000 bicicletas. Además de una deserción de mas de 4.000 abonados, esto atribuible al incertidumbre generada por la operación de compra del ayuntamiento. fuente=  https://www.elmundo.es/madrid/2017/09/02/59a996ba22601d99558b463e.html

# %%
out = sns.boxplot(x="ano", y="total_abonos" , data=bicis_usos)
plt.xlabel('Años')
plt.ylabel('Cantidad Usos')
plt.title('Uso Total Abonados anuales por Año')
# Out:
# Text(0.5, 1.0, 'Uso Total Abonados anuales por Año')

# %% [markdown]
# El siguiente análisis lo aplicamos con una gráfica tipo **Lineplot** y en ella podemos observar de forma individualizada el comportamiento de los **Abonados Anuales** durante los 5 años: un arranque el primer año que en menos de 6 meses obtiene aprox 6.000 usos, aumenta a mas de 8.000 usos en 2015 y en 2016 cae para reponerse nuevamente a partir de 2017.

# %%
out = sns.lineplot(data=bicis_usos_melt[(bicis_usos_melt.tipo_usuario=='abono_anual')] , x='ano',
                   y='cantidad_usos', hue='tipo_usuario', ci=0, err_style='bars',palette="Set1",
                   linewidth=2.5, legend='full')

plt.xlabel('Años')
plt.ylabel('Cant Uso')
plt.title('Cant uso Abonado anual por año')
# Out:
# Text(0.5, 1.0, 'Cant uso Abonado anual por año')

# %% [markdown]
# Ahora para completar el analisis de la relación de las variables de *Cantidad de uso* por *Año*, observamos a través de otro **lineplot**, pero en este caso aplicado a los **Abonados ocasionales**, que el comportamiento tiene una tendencia parecida a los **Abonados Anuales** al principio. Que aunque la escala es totalmente diferente, podemos ver el mismo ascenso el primer y segundo año, para caer nuevamente en 2016, pero a diferencia del otro tipo de usuario, este no mantiene un ascenso en 2017 y 2018, sino que se mantiene estable entre los 175 y 200 usos anuales.
# Revisando la baja demanda de estos abonados, se obtiene información que el sistema está enfocado en los abonados anuales, entendiendo que estos realemte hacen parte del sistema multimodal que quiere implementar el ayuntamiendo, dandole al sistema un caracter de transporte complementario y no potenciar p.e, el uso del sistema por el turismo.

# %%
out = sns.lineplot(data=bicis_usos_melt[(bicis_usos_melt.tipo_usuario=='abono_ocasional')] , x='ano',
                   y='cantidad_usos', hue='tipo_usuario', ci=0, err_style='bars',palette="Set2",
                   linewidth=2.5, legend='full')

plt.xlabel('Años')
plt.ylabel('Cant Uso')
plt.title('Cant uso Abonado ocasional por año')
# Out:
# Text(0.5, 1.0, 'Cant uso Abonado ocasional por año')

# %% [markdown]
# ****GRAFICAS DE ESCALA DIARIA****

# %% [markdown]
# ***MEDIA DE USO ABONADOS ANUALES POR DÍA DE LA SEMANA***
# A continuación un ***Barplot***.
# Esta gráfica contiene la media de los usos por días de los 5 años que tiene de vigencia el sistema.
# Vemos como la usabilidad los **Abonados Anuales** tiene un comportamiento intenso durante los días hábiles, especialmente entre martes y jueves. Este desempeño contrasta con el de los **Abonados Ocasionales** que veremos a continuación.

# %%
sns.barplot(x='dia_semana', y='abono_anual', estimator=np.mean, data=bicis_usos, palette="Set3")
plt.xlabel('Día de la Semana')
plt.ylabel('Cantidad Usos')
plt.title('Media de Uso de Abonados Anuales por Día de la Semana')
# Out:
# Text(0.5, 1.0, 'Media de Uso de Abonados Anuales por Día de la Semana')

# %% [markdown]
# En la siguiente gráfica **Barplot** podemos observar el comportamiento de la media de uso por día de la semana de los **Abonados Ocasionales**. Claramente los fines de semana es cuando aumenta el uso por parte de este tipo de usuario, que puede ser asociado al turismo. Tener claro este comportamiento es fundamental, aunque las cifras puedan parecer muy bajas, sí que se detecta una tendencia qe podría ser explotada mas adelante con ofertas adaptadas a estos días.

# %%
sns.barplot(x='dia_semana', y='abono_ocasional', estimator= np.mean, data=bicis_usos,palette="Set3")
plt.xlabel('Día de la Semana')
plt.ylabel('Cantidad Usos')
plt.title('Media de Uso de Abonados Ocasionales por Día de la Semana')
# Out:
# Text(0.5, 1.0, 'Media de Uso de Abonados Ocasionales por Día de la Semana')

# %% [markdown]
# ****GRAFICAS DE ESCALA MENSUAL****

# %% [markdown]
# Para continuar con el análisis del comportamiento por **Mes** de los usuarios con **Abono Anual** usaremos gráficas tipo **Pointplot** que ideales para puntualizar cortes. En ese caso observamos como el segundo trimestre presenta siempre alzas en su comportamiento, también los meses de *Agosto* y *Septiembre* se presentan aumentos todos los años. Y para cerar las bajas que se presentan siempre para para verano y los meses de *Dicembre*  a *Marzo*, fácilmente atribuíble a epocas de vacaciones y las bajas temperaturas del invierno, respectivamente.

# %%
out = sns.pointplot(data=bicis_usos_melt[bicis_usos_melt.tipo_usuario=='abono_anual'],x='mes',
                   y='cantidad_usos', hue='ano', ci=0, err_style='bars',palette="tab10",
                   linewidth=2.5, legend='full')

plt.xlabel('Mes N°')
plt.ylabel('Cantidad Uso')
plt.title('Uso mensual de abonado anual por mes')
# Out:
# Text(0.5, 1.0, 'Uso mensual de abonado anual por mes')

# %% [markdown]
# En el caso de los **Abonados Ocasionales** los meses de *mayo, junio, septiembre * y * octubre* son los momentos de mayor alza en la demanda del sistema. Igualmente con caídas muy pronunciadas desde *diciembre* hasta comienzos de *marzo*.

# %%
out = sns.pointplot(data=bicis_usos_melt[bicis_usos_melt.tipo_usuario=='abono_ocasional'],x='mes',
                   y='cantidad_usos', hue='ano', ci=0, err_style='bars',palette="Set3",
                   linewidth=2.5, legend='full')

plt.xlabel('Mes N°')
plt.ylabel('Cant Uso')
plt.title('Uso mensual abonado ocasional por mes')
# Out:
# Text(0.5, 1.0, 'Uso mensual abonado ocasional por mes')

# %% [markdown]
# ****CRUCE DE TABLAS (Merge)****
#
# Para darle mas profundidad y contexto a la información sobre el uso de las bicicletas hemos optado por realizar cruces con el clima, entonces podremos ver la relación de los días de lluvia y la temperatura con el uso del sistema

# %% [markdown]
# Importamos una tabla del clima la cual trabajamos en otro *Notebook*.

# %%
clima= pd.read_csv('dat/all_weather_data.csv', sep=',', index_col=False)
clima.head()
# Out:
#    Unnamed: 0        date hour_temp_max hour_temp_min  precipitation  \
# 0           0  2015-01-01      13:30:00      05:20:00            0.0
# 1           1  2015-01-02      15:10:00      07:20:00            0.0
# 2           2  2015-01-03      14:50:00      08:10:00            0.0
# 3           3  2015-01-04      13:15:00      08:10:00            0.0
# 4           4  2015-01-05      15:20:00      07:10:00            0.0
#
#    temp_max  temp_media  temp_min  wind_speed  wind_speed_max
# 0      10.4         4.7      -1.0         0.8             3.9
# 1      12.0         5.5      -1.0         0.6             3.9
# 2      11.4         6.3       1.2         0.3             3.6
# 3      14.0         7.7       1.4         0.3             3.3
# 4      12.0         6.8       1.5         1.4             5.3

# %% [markdown]
# Esta tabla también amerita modificar el formato de la fecha, para lo cual aplicamos función *datetime.strptime*.

# %%
def cast_date(date):
    return datetime.strptime(date, '%Y-%m-%d')

clima['date'] = clima.date.apply(cast_date)

# %% [markdown]
# Ahora implementamos la función *merge* para cruzar la tabla clima con la tabla usos. Tabla que llamaremos **climabicis**

# %%
climabicis=bicis_usos.merge(clima, left_on='fecha', right_on='date')
climabicis.head()
# Out:
#        fecha  abono_anual  abono_ocasional  total_abonos   ano  mes  \
# 0 2015-01-01         2018              149          2167  2015    1
# 1 2015-01-02         2880              153          3033  2015    1
# 2 2015-01-03         3187              170          3357  2015    1
# 3 2015-01-04         3296              154          3450  2015    1
# 4 2015-01-05         4039              117          4156  2015    1
#
#   dia_semana  Unnamed: 0       date hour_temp_max hour_temp_min  \
# 0     Jueves           0 2015-01-01      13:30:00      05:20:00
# 1    Viernes           1 2015-01-02      15:10:00      07:20:00
# 2     Sabádo           2 2015-01-03      14:50:00      08:10:00
# 3    Domingo           3 2015-01-04      13:15:00      08:10:00
# 4      Lunes           4 2015-01-05      15:20:00      07:10:00
#
#    precipitation  temp_max  temp_media  temp_min  wind_speed  wind_speed_max
# 0            0.0      10.4         4.7      -1.0         0.8             3.9
# 1            0.0      12.0         5.5      -1.0         0.6             3.9
# 2            0.0      11.4         6.3       1.2         0.3             3.6
# 3            0.0      14.0         7.7       1.4         0.3             3.3
# 4            0.0      12.0         6.8       1.5         1.4             5.3

# %% [markdown]
# Inspeccionanamos nuevamente la tabla resultado del *merge* y además verificamos el tipo de datos obtenido.

# %%
climabicis.tail()
# Out:
#           fecha  abono_anual  abono_ocasional  total_abonos   ano  mes  \
# 1456 2018-12-27         7282              151          7433  2018   12
# 1457 2018-12-28         7386              256          7642  2018   12
# 1458 2018-12-29         5584              250          5834  2018   12
# 1459 2018-12-30         5114              301          5415  2018   12
# 1460 2018-12-31         4718              283          5001  2018   12
#
#      dia_semana  Unnamed: 0       date hour_temp_max hour_temp_min  \
# 1456     Jueves        1456 2018-12-27      14:30:00      07:40:00
# 1457    Viernes        1457 2018-12-28      15:10:00      08:10:00
# 1458     Sabádo        1458 2018-12-29      15:10:00      07:15:00
# 1459    Domingo        1459 2018-12-30      14:50:00      06:30:00
# 1460      Lunes        1460 2018-12-31      15:30:00      07:50:00
#
#       precipitation  temp_max  temp_media  temp_min  wind_speed  \
# 1456            0.0      10.5         6.2       2.0         0.6
# 1457            0.0      12.7         7.1       1.5         1.4
# 1458            0.0      11.9         8.0       4.0         1.7
# 1459            0.0      14.2         8.7       3.2         1.1
# 1460            0.0      13.4         7.0       0.7         0.6
#
#       wind_speed_max
# 1456             3.3
# 1457             5.8
# 1458             7.8
# 1459             7.5
# 1460             5.3

# %% [markdown]
# La tabla clima tiene información hasta Enero del 2019, por lo que procedemos a eliminar los datos con fecha superior a 31-12-2018, que es la última fecha con información de uso de Bicimad.

# %%
climabicis = climabicis[climabicis.mes<2019]

# %% [markdown]
# Además realizamos la eliminación de las columnas que no necesitamos, para lo que nuevamente usamos la función *Drop*.

# %%
climabicis.drop(climabicis.columns[[7,8,9,10,12,14,15,16]], axis=1, inplace=True)
climabicis.tail()
# Out:
#           fecha  abono_anual  abono_ocasional  total_abonos   ano  mes  \
# 1456 2018-12-27         7282              151          7433  2018   12
# 1457 2018-12-28         7386              256          7642  2018   12
# 1458 2018-12-29         5584              250          5834  2018   12
# 1459 2018-12-30         5114              301          5415  2018   12
# 1460 2018-12-31         4718              283          5001  2018   12
#
#      dia_semana  precipitation  temp_media
# 1456     Jueves            0.0         6.2
# 1457    Viernes            0.0         7.1
# 1458     Sabádo            0.0         8.0
# 1459    Domingo            0.0         8.7
# 1460      Lunes            0.0         7.0

# %%
climabicis.dtypes
# Out:
# fecha              datetime64[ns]
# abono_anual               float64
# abono_ocasional           float64
# total_abonos              float64
# ano                       float64
# mes                       float64
# dia_semana                 object
# precipitation             float64
# temp_media                float64
# dtype: object

# %% [markdown]
# Ahora solo falta convertir las columnas tipo float como **'abono_anual'**, **'Abono_ocasional'** y **'Año'** entre otros a números enteros(int). Para esto aplicamos función **lambda** por cada columna.

# %%
climabicis['ano']= climabicis.apply(lambda fila: int(fila['ano']), axis=1)
climabicis['abono_anual']= climabicis.apply(lambda fila: int(fila['abono_anual']), axis=1)
climabicis['abono_ocasional']= climabicis.apply(lambda fila: int(fila['abono_ocasional']), axis=1)
climabicis['total_abonos']= climabicis.apply(lambda fila: int(fila['total_abonos']), axis=1)
climabicis['mes']= climabicis.apply(lambda fila: int(fila['mes']), axis=1)

# %% [markdown]
# Confirmamos el cambio de tipo y ya quedó listo para trabajar con gráficas.

# %%
climabicis.dtypes
# Out:
# fecha              datetime64[ns]
# abono_anual                 int64
# abono_ocasional             int64
# total_abonos                int64
# ano                         int64
# mes                         int64
# dia_semana                 object
# precipitation             float64
# temp_media                float64
# dtype: object

# %% [markdown]
# En esta gráfica detectamos claramente que si cruzamos el uso total del sistema con la temperatura encontraremos una relación directa: a mayor temperatura, mayor uso de ciclas. Sin embargo, cuando la media de la temperatura supera los 25 grados, ya afecta negativamente el uso del sistema,es entre 20 y 25 la condición ideal de temperatura para el uso del sistema. Lo que habíamos confirmado antes con el uso por mes, donde en los meses de invierno reflejan una gran disminución de usos.

# %%
out = sns.regplot(x='temp_media', y='total_abonos', data=climabicis )
out = sns.scatterplot(x='temp_media', y='total_abonos', data=climabicis , hue='temp_media', palette='YlOrRd')

plt.xlabel('Temperatura')
plt.ylabel('Cant Uso')
plt.title('Cantidad uso total vs Temperatura')
# Out:
# Text(0.5, 1.0, 'Cantidad uso total vs Temperatura')

# %% [markdown]
# Para revisar la relación entre la lluvia y el uso de bicicleas del sistema, podemos ver que que esta variable no afecta directamente el sistema. Los días que hubo 'cero' lluvias, evidentemente hay uso del sistema, pero los días que llovió no se ve tan afectado dicho uso. Realmente llueve poco en Madrid y cuando sucede, no es impedimento.

# %%
out = sns.scatterplot(x='precipitation', y='total_abonos', data=climabicis, palette="BuGn")

plt.xlabel('Nivel de precipitación')
plt.ylabel('Cantidad uso total')
plt.title('Cantidad uso total vs Nivel de precipitación')
# Out:
# Text(0.5, 1.0, 'Cantidad uso total vs Nivel de precipitación')
