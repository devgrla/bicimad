# %%
import pandas as pd
import numpy as np
from datetime import date, datetime

# %%
altas_usuarios= pd.read_excel('altas_usuarios.xls', index_col=None)
altas_usuarios.head()
# Out:
#        fecha  abonados anuales sin ttp  abonados anuales con ttp  \
# 0 2014-06-23                        47                        44
# 1 2014-06-24                        21                        19
# 2 2014-06-25                       193                       180
# 3 2014-06-26                       150                       113
# 4 2014-06-27                       185                       155
#
#    total abonados anuales  abonado ocas 1 día   abonado ocas 3 días   \
# 0                      91                    2                     0
# 1                      40                    2                     1
# 2                     373                    5                     0
# 3                     263                    7                     0
# 4                     340                   13                     1
#
#    abonado ocas 5 días   total abonado ocas
# 0                     0                   2
# 1                     0                   3
# ...

# %%
altas_usuarios.tail()
# Out:
#           fecha  abonados anuales sin ttp  abonados anuales con ttp  \
# 1648 2018-12-27                       -21                       -20
# 1649 2018-12-28                        -6                        14
# 1650 2018-12-29                         5                        21
# 1651 2018-12-30                         6                        21
# 1652 2018-12-31                         0                        -5
#
#       total abonados anuales  abonado ocas 1 día   abonado ocas 3 días   \
# 1648                     -41                   51                    20
# 1649                       8                   96                     8
# 1650                      26                   93                    20
# 1651                      27                  112                    10
# 1652                      -5                  103                    11
#
#       abonado ocas 5 días   total abonado ocas
# 1648                     8                  79
# ...

# %%
altas_usuarios.columns=['fecha','abon_anuales_sin_ttp', 'abo_anuales_con_ttp', 'total_abo_anuales', 'abo_ocas_1_dia', 
                        'abo_ocas_3_dias', 'abo_ocas_5_dias', 'total_abo_ocas']
altas_usuarios.head()
# Out:
#        fecha  abon_anuales_sin_ttp  abo_anuales_con_ttp  total_abo_anuales  \
# 0 2014-06-23                    47                   44                 91
# 1 2014-06-24                    21                   19                 40
# 2 2014-06-25                   193                  180                373
# 3 2014-06-26                   150                  113                263
# 4 2014-06-27                   185                  155                340
#
#    abo_ocas_1_dia  abo_ocas_3_dias  abo_ocas_5_dias  total_abo_ocas
# 0               2                0                0               2
# 1               2                1                0               3
# 2               5                0                1               6
# 3               7                0                0               7
# 4              13                1                0              14

# %%
altas_usuarios.dtypes
# Out:
# fecha                   datetime64[ns]
# abon_anuales_sin_ttp             int64
# abo_anuales_con_ttp              int64
# total_abo_anuales                int64
# abo_ocas_1_dia                   int64
# abo_ocas_3_dias                  int64
# abo_ocas_5_dias                  int64
# total_abo_ocas                   int64
# dtype: object

# %%
altas_usuarios.shape
# Out:
# (1653, 8)

# %%
altas_usuarios.describe()
# Out:
#        abon_anuales_sin_ttp  abo_anuales_con_ttp  total_abo_anuales  \
# count           1653.000000          1653.000000        1653.000000
# mean              15.635814            24.124017          39.759831
# std               48.281652            44.804131          89.633703
# min             -790.000000          -577.000000       -1367.000000
# 25%               -8.000000             1.000000          -7.000000
# 50%               13.000000            23.000000          36.000000
# 75%               37.000000            48.000000          82.000000
# max              236.000000           180.000000         391.000000
#
#        abo_ocas_1_dia  abo_ocas_3_dias  abo_ocas_5_dias  total_abo_ocas
# count     1653.000000      1653.000000      1653.000000     1653.000000
# mean        68.096794         6.112523         2.611010       76.820327
# std         60.723585         5.811041         2.545575       65.261310
# ...

# %%
import psycopg2 as pg
conn = pg.connect("postgres://xseed:LosTilos114@postgre-sqltest.cpdeokpzufj1.us-west-2.rds.amazonaws.com:5432/postgres")

cur = conn.cursor()
for index, row in altas_usuarios.iterrows():
    update_query = "update user_total_statistics set new_anual_users_ttp={0}, new_anual_users_no_ttp={2}, new_occasional_users_1day={3}, new_occasional_users_3day={4}, new_occasional_users_5day={5} where date = '{1}' ".format(row.abon_anuales_sin_ttp, row.fecha, row.abo_anuales_con_ttp, row.abo_ocas_1_dia,row.abo_ocas_3_dias, row.abo_ocas_5_dias)
    cur.execute(update_query)
conn.commit()
conn.close()
