# %%
import funciones_rutas as fr #Funciones customizadas

# %% [markdown]
# # Visualización de movimientos de bicicletas
#
# Se utiliza el GPS de la bicicleta para determinar los movimientos

# %% [markdown]
# Por ejemplo, se visualiza en el siguiente mapa los recorridos de las bicicletas (usuarios anuales y ocasionales) para el periodo seleccionado.

# %%
fecha_origen= '2018-06-10 08:00:00'
fecha_destino='2018-06-30 10:00:00'
user_type_code = '(0,1,2)'

# %%
fr.get_movements_lines(fecha_origen, fecha_destino, user_type_code, 2000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **¿Cómo son los movimientos de los trabajadores para el mismo período?**

# %%
user_type_code = '(3)'
fr.get_movements_lines(fecha_origen, fecha_destino, user_type_code, 1500)

# %% [markdown]
# # Movimientos entre estaciones
#
# Puede ser de interés establecer un filtro entre algunas estaciones para visualizar como son los movimientos entre ellas.
# Se pueden modificar los filtros y visualizar en mapa.
#
# Solamente se puede visualizar un limite de 2000 movimientos. Es por eso que se ordenan aleatoriamente los resultados para que representen a varios de los días seleccionados.

# %%
estacion_origen = 29 
estacion_destino = 151 
fecha_origen= '2017-04-10 08:00:00'
fecha_destino='2019-01-30 10:00:00'
user_type_code = '(0,1,2)'

# %%
fr.get_routes_between_stations(estacion_origen, estacion_destino, fecha_origen, fecha_destino, user_type_code)
