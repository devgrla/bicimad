# %% [markdown]
# # Entradas y Salidas de bicicletas a estaciones
#
# Se pretende visualizar como es el comportamiento de las estaciones según la cantidad de bicicletas que se enganchan y desenganchan en cada una, teniendo en cuenta día de la semana y horario.

# %%
import json
import pandas as pd
from PIL import Image, ImageDraw
import geopandas as gpd
from shapely.geometry import Point
import geopandas as gpd
import folium
import psycopg2
conn = psycopg2.connect("host='postgre-sqltest.cpdeokpzufj1.us-west-2.rds.amazonaws.com' port=5432 dbname='postgres' user=xseed password=LosTilos114")
crs = {'init': 'epsg:4326'}
import numpy as np
import scipy.ndimage.filters
import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap, rgb_to_hsv, hsv_to_rgb
import funciones_movimientos as fm #Funciones customizadas

# %% [markdown]
# Consulta sobre la base de datos, NO teniendo en cuenta los movimientos realizados por los trabajadores de Bicimad. Esos se analizarán aparte.

# %%
fecha_origen = '2018-03-21 08:00:00'
fecha_destino = '2018-06-21 23:00:00'
user_type_codes = '(0,1,2)' #Todos menos los trabajadores
data = fm.get_data_for_trip_counts(fecha_origen, fecha_destino,user_type_codes)

# %% [markdown]
# En este primer ejemplo se quiere visualizar como es la migración de las bicicletas, si hay alguna relación entre la hora del día y las salidas o arribos de las bicis a las estaciones

# %% [markdown]
# Asignamos un color diferente según el balance entre salidas y arribos a la estación en esa hora. Si hay mas salidas que arribos el color es naranja, de lo contrario se utiliza azul. El radio depende del número del balance, cuanto mayor el número mayor el radio.

# %%
# Ver comportamiento entre las 7 y 9 AM dias laborales
trip_counts = fm.get_trip_counts_by_hour(7,9, data, weekends = 0)
fm.plot_station_counts(trip_counts, data, radius_divisor = 50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Tabla vinculada al mapa anterior
tmp = fm.get_table_counts_by_hour(trip_counts, max_rows = 200, orderAsc = 0)
tmp
# Out:
#                                   Estacion           Barrio  Llegadas  \
# 55                       Plaza de Lavapiés      Embajadores       440
# 75                         Menéndez Pelayo        Jerónimos       549
# 125               Santa María de la Cabeza  Palos de Moguer       547
# 41                      Plaza de la Cebada          Palacio       506
# 40                     Plaza de los Carros          Palacio       208
# 79                       Puerta de Granada         Pacífico       611
# 45                           Jesús y María      Embajadores        47
# 171                             Segovia 45         Imperial       821
# 44                            Santa Isabel      Embajadores       334
# 164                   Fernando el Católico         Arapiles       638
# 71                         Doce de Octubre       Niño Jesús       343
# 145         Glorieta de los Cuatro Caminos       Rios Rosas       601
# 83                              Niño Jesús         Estrella       170
# 76              Puerta de Mariano de Cavia       Niño Jesús       132
# 135                             San Germán   Cuatro Caminos       250
# 159              General Álvarez de Castro        Trafalgar      1377
# 157                           José Abascal       Rios Rosas       497
# 129                        Metro Pirámides          Acacias       483
# 39                     Plaza San Francisco          Palacio       535
# 47                        Puerta de Toledo      Embajadores       756
# 73                     Plaza de los Astros         Estrella       461
# 74                    Puerta del Pacífico         Jerónimos       791
# 48                    Ribera de Curtidores          Acacias       201
# 49                           Embajadores 1          Acacias       201
# 130                  Paseo de la Esperanza          Acacias       278
# 124                   Palos de la Frontera  Palos de Moguer       528
# 102                             Jorge Juan             Goya       460
# 70              Puerta del Doce de Octubre        Jerónimos       812
# 46                 Plaza de Nelson Mandela      Embajadores       111
# 72                        Sainz de Baranda         Estrella       654
# ..                                     ...              ...       ...
# 103                              Velázquez        Recoletos       700
# 108                                Colón B        Recoletos       757
# 10                  Marqués de la Ensenada         Justicia       791
# 133                         Castellana 164     Nueva España       883
# 0                         Puerta del Sol A              Sol      1173
# 155                José Gutiérrez Abascal           El Viso       870
# 143    Castellana frente a Hermanos Pinzón          El Viso       792
# 88                                   Ayala        Recoletos      1118
# 68                                Espalter        Jerónimos      1040
# 105                             Castellana        Recoletos       830
# 139  General Perón con Poeta Joan Maragall   Cuatro Caminos      1031
# 95                     Biblioteca Nacional        Recoletos      1321
# 126                      Santa Engracia 14        Trafalgar      1477
# 111                   Marqués de Salamanca       Castellana      1327
# 96                              Villanueva        Recoletos       954
# 89                      Embajada de Italia       Castellana      1327
# 163                          Castellana 42       Castellana      1196
# 69                  Puerta del Ángel Caído        Jerónimos      1352
# 141                              Orense 12   Cuatro Caminos      1367
# 31                        Marqués de Cubas           Cortes      1355
# 106                                Serrano        Recoletos      1279
# 8                          Alonso Martínez          Almagro      1744
# 20                       Banco de España A         Justicia      1310
# 66                           Antonio Maura        Jerónimos      1397
# 91                        General Pardiñas        Recoletos      1535
# 87                                 Cibeles        Jerónimos      1458
# 109                               Columela        Recoletos      1537
# 62               Plaza de la Independencia        Jerónimos      1783
# 104                        Ortega y Gasset       Castellana      1882
# 158                          Velázquez 130          El Viso      2383
#
#      Salidas  Balance
# 55      1588     1148
# 75      1696     1147
# 125     1667     1120
# 41      1561     1055
# 40      1240     1032
# 79      1641     1030
# 45      1010      963
# 171     1775      954
# 44      1281      947
# 164     1580      942
# 71      1235      892
# 145     1474      873
# 83      1039      869
# 76       966      834
# 135     1058      808
# 159     2149      772
# 157     1256      759
# 129     1238      755
# 39      1286      751
# 47      1476      720
# 73      1175      714
# 74      1499      708
# 48       909      708
# 49       882      681
# 130      945      667
# 124     1180      652
# 102     1110      650
# 70      1429      617
# 46       720      609
# 72      1260      606
# ..       ...      ...
# 103       92     -608
# 108      138     -619
# 10       164     -627
# 133      199     -684
# 0        462     -711
# 155      156     -714
# 143       69     -723
# 88       357     -761
# 68       279     -761
# 105       65     -765
# 139      257     -774
# 95       536     -785
# 126      689     -788
# 111      523     -804
# 96        83     -871
# 89       403     -924
# 163      211     -985
# 69       366     -986
# 141      377     -990
# 31       359     -996
# 106      269    -1010
# 8        607    -1137
# 20       154    -1156
# 66       204    -1193
# 91       275    -1260
# 87       193    -1265
# 109      224    -1313
# 62       403    -1380
# 104      457    -1425
# 158      456    -1927
#
# [172 rows x 5 columns]

# %%
# Ver comportamiento de 18 a 20 PM
trip_counts = fm.get_trip_counts_by_hour(18,20, data, weekends = 0)
fm.plot_station_counts(trip_counts, data, radius_divisor = 20)

# %%
#Tabla vinculada al mapa anterior
fm.get_table_counts_by_hour(trip_counts, max_rows = 200, orderAsc = 1)

# %% [markdown]
# Se puede visualizar como hay regiones que varian su balance entradas/salidas según la hora del día. Muchas de las que tienen mayor cantidad de partidas durante la mañana son de las que tienen más arribos al finalizar el día. Las del centro (que son las estaciones más utilizadas) mantienen una demanda constante en cualquier horario del día.

# %% [markdown]
# # Fines de semana

# %%
trip_counts = fm.get_trip_counts_by_hour(7,9, data, weekends = 1)
fm.plot_station_counts(trip_counts, data, radius_divisor = 20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Comportamiento de los trabajadores de bicimad
#
# Queremos visualizar cuales son las estaciones a la que mas bicicletas aportan los trabajadores y de donde obtienen más para llevar a otras.

# %%
fecha_origen = '2018-03-21 08:00:00'
fecha_destino = '2018-06-21 23:00:00'
user_type_codes = '(3)'
data_trabajadores = fm.get_data_for_trip_counts(fecha_origen, fecha_destino,user_type_codes)

# %%
#De 7 a 9 AM
trip_counts = fm.get_trip_counts_by_hour(7,9, data_trabajadores, weekends = 0)
fm.plot_station_counts(trip_counts, data_trabajadores, radius_divisor = 30)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Tabla vinculada al mapa anterior
fm.get_table_counts_by_hour(trip_counts, max_rows = 200, orderAsc = 1)
# Out:
#                                   Estacion           Barrio  Llegadas  \
# 73                         Menéndez Pelayo        Jerónimos     560.0
# 77                       Puerta de Granada         Pacífico     523.0
# 121               Santa María de la Cabeza  Palos de Moguer     464.0
# 39                      Plaza de la Cebada          Palacio     364.0
# 53                       Plaza de Lavapiés      Embajadores     349.0
# 38                     Plaza de los Carros          Palacio     326.0
# 166                             Segovia 45         Imperial     296.0
# 159                   Fernando el Católico         Arapiles     329.0
# 72                    Puerta del Pacífico         Jerónimos     236.0
# 154              General Álvarez de Castro        Trafalgar     312.0
# 131                             San Germán   Cuatro Caminos     226.0
# 71                     Plaza de los Astros         Estrella     231.0
# 69                         Doce de Octubre       Niño Jesús     188.0
# 141         Glorieta de los Cuatro Caminos       Rios Rosas     191.0
# 126                  Paseo de la Esperanza          Acacias     174.0
# 45                        Puerta de Toledo      Embajadores     165.0
# 134                        General Perón 1   Cuatro Caminos     141.0
# 152                           José Abascal       Rios Rosas     191.0
# 46                    Ribera de Curtidores          Acacias     138.0
# 74              Puerta de Mariano de Cavia       Niño Jesús     126.0
# 147                       Bravo Murillo 44       Rios Rosas     149.0
# 37                     Plaza San Francisco          Palacio     125.0
# 125                        Metro Pirámides          Acacias     137.0
# 120                   Palos de la Frontera  Palos de Moguer     129.0
# 81                              Niño Jesús         Estrella     122.0
# 68              Puerta del Doce de Octubre        Jerónimos     116.0
# 165                             Segovia 26          Palacio      82.0
# 128                  Paseo de las Delicias         Delicias     113.0
# 54                                 Barceló         Justicia      66.0
# 83                             Valderribas          Adelfas      83.0
# ..                                     ...              ...       ...
# 107                   Marqués de Salamanca       Castellana      21.0
# 135  General Perón con Poeta Joan Maragall   Cuatro Caminos       2.0
# 86                                   Ayala        Recoletos       5.0
# 18                       Banco de España A         Justicia      35.0
# 79                                Atocha B        Jerónimos      13.0
# 78                                Atocha A        Jerónimos      13.0
# 102                                Serrano        Recoletos      23.0
# 129                         Castellana 164     Nueva España      38.0
# 143                         Castellana 106          El Viso       5.0
# 119                          Méndez Álvaro           Atocha      18.0
# 150                José Gutiérrez Abascal           El Viso       5.0
# 88                        General Pardiñas        Recoletos      38.0
# 101                             Castellana        Recoletos      40.0
# 151                           Cea Bermúdez       Gaztambide      45.0
# 118                            Juan Martín  Palos de Moguer       5.0
# 87                      Embajada de Italia       Castellana       4.0
# 158                          Castellana 42       Castellana      16.0
# 92                     Biblioteca Nacional        Recoletos      41.0
# 66                                Espalter        Jerónimos       6.0
# 67                  Puerta del Ángel Caído        Jerónimos      13.0
# 7                          Alonso Martínez          Almagro      20.0
# 124                    Paseo de la Florida    Casa de Campo      14.0
# 137                              Orense 12   Cuatro Caminos      37.0
# 64                           Antonio Maura        Jerónimos      16.0
# 105                               Columela        Recoletos      21.0
# 100                        Ortega y Gasset       Castellana      32.0
# 85                                 Cibeles        Jerónimos      37.0
# 60               Plaza de la Independencia        Jerónimos      33.0
# 153                          Velázquez 130          El Viso      20.0
# 29                        Marqués de Cubas           Cortes       NaN
#
#      Salidas  Balance
# 73        14   -546.0
# 77        23   -500.0
# 121       27   -437.0
# 39         6   -358.0
# 53        19   -330.0
# 38         2   -324.0
# 166       16   -280.0
# 159       76   -253.0
# 72         6   -230.0
# 154       91   -221.0
# 131       17   -209.0
# 71        24   -207.0
# 69         8   -180.0
# 141       15   -176.0
# 126       11   -163.0
# 45        11   -154.0
# 134       13   -128.0
# 152       63   -128.0
# 46        11   -127.0
# 74         4   -122.0
# 147       28   -121.0
# 37         5   -120.0
# 125       22   -115.0
# 120       20   -109.0
# 81        19   -103.0
# 68        17    -99.0
# 165        3    -79.0
# 128       43    -70.0
# 54         3    -63.0
# 83        24    -59.0
# ..       ...      ...
# 107       67     46.0
# 135       48     46.0
# 86        55     50.0
# 18       111     76.0
# 79       102     89.0
# 78       104     91.0
# 102      118     95.0
# 129      140    102.0
# 143      107    102.0
# 119      129    111.0
# 150      133    128.0
# 88       167    129.0
# 101      173    133.0
# 151      181    136.0
# 118      145    140.0
# 87       150    146.0
# 158      165    149.0
# 92       191    150.0
# 66       168    162.0
# 67       187    174.0
# 7        200    180.0
# 124      194    180.0
# 137      224    187.0
# 64       469    453.0
# 105      475    454.0
# 100      536    504.0
# 85       641    604.0
# 60       652    619.0
# 153     1136   1116.0
# 29         5      NaN
#
# [167 rows x 5 columns]

# %%
#Ver comportamiento trabajadores de 18 a 20
trip_counts = fm.get_trip_counts_by_hour(18,20, data_trabajadores, weekends = 0)
fm.plot_station_counts(trip_counts, data_trabajadores, radius_divisor = 10)

# %% [markdown]
# # Visualización animada según hora del día

# %%
    locations = data.groupby(["hour","code_station_departure"]).first()
    # and select only the tree columns we are interested in
    locations = locations.loc[:, ["latitude_departure",
                              "longitude_departure",
                              "name_departure"]]
    
    subset = data
    subset_arrival = data
    
    departure_counts =  subset.groupby(["hour","code_station_departure"]).count()
    # select one column
    departure_counts = departure_counts.iloc[:,[0]]
    # and rename that column
    departure_counts.columns= ["Departure Count"]

    arrival_counts =  subset_arrival.groupby(["hour","code_station_arrival"]).count()
    # select one column
    arrival_counts = arrival_counts.iloc[:,[0]]
    # and rename that column
    arrival_counts.columns= ["Arrival Count"]
    trip_counts_by_hour = departure_counts.join(locations, on=["hour","code_station_departure"]).join(arrival_counts, on = ["hour","code_station_departure"])
    
    trip_counts_by_hour = trip_counts_by_hour.reset_index()
    trip_counts_by_hour

# %%
import os
os.environ["PATH"] += os.pathsep + "."

# %%
def interpolate(df1, df2, x):
    """return a weighted average of two dataframes"""
    df = df1 * (1 - x) + df2 * x
    return df.replace(np.nan, 0)
  

def get_trip_counts_by_minute(float_hour):
    """get an interpolated dataframe for any time, based
    on hourly data"""
    
    columns = ["latitude_departure",
               "longitude_departure",
               "Departure Count",
               "Arrival Count"]
    df1 = get_trip_counts_by_hour(int(float_hour))
    df2 = get_trip_counts_by_hour(int(float_hour) + 1)
    
    df = interpolate(df1.loc[:,columns], 
                     df2.loc[:,columns], 
                     float_hour % 1)
    
    df["name_departure"] = df1["name_departure"]
    return df

# %%
data2 = get_trip_counts_by_minute(9.5)
plot_station_counts(data2)

# %%
def go_arrivals_frame(i, hour_of_day, save_path):
    
    # create the map object
    data = get_trip_counts_by_minute(hour_of_day)
    my_frame = plot_station_counts(data)
    
    # generate the png file as a byte array
    png = my_frame._to_png()
    
    #  now add a caption to the image to indicate the time-of-day.
    hour = int(hour_of_day)
    minutes = int((hour_of_day % 1) * 60)
    
    # create a PIL image object
    image = Image.open(io.BytesIO(png))
    draw = ImageDraw.ImageDraw(image)
    
    # load a font
    font = ImageFont.truetype("Roboto-Light.ttf", 30)
    
    # draw time of day text
    draw.text((20,image.height - 50), 
              "time: {:0>2}:{:0>2}h".format(hour, minutes),
              fill=(255, 255, 255), 
              font=font)
    
    # draw title
    draw.text((image.width - 400,20), 
              "Net Arrivals vs Time of Day",
              fill=(255, 255, 255), 
              font=font)
    
    # write to a png file
    filename = os.path.join(save_path, "frame_{:0>5}.png".format(i))
    image.save(filename, "PNG")
    return image

# %%
arrival_times = np.arange(6, 23, .2)
frames_to_redo = [27, 41, 74, 100, 105]
for i in frames_to_redo:
    hour = arrival_times[i]
    go_arrivals_frame(i, hour, "frames")

# %% [markdown]
# # Relaciones entre estaciones
#
# Se pretende visualizar ahora como se relacionan las estaciones según la hora del día. O sea como es la relación origen - destino en los movimientos de las bicicletas.

# %% [markdown]
# Veo en tabla viajes entre distritos por hora.

# %%
fecha_origen = '2018-06-21 08:00:00'
fecha_destino = '2018-09-21 23:00:00'
user_type_codes = '(0,1,2)' #Todos menos los trabajadores
data = fm.get_data_for_trip_counts(fecha_origen, fecha_destino,user_type_codes)

# %%
tmp = data.groupby(['hour','distrito_departure', 'distrito_arrival']).count().reset_index().loc[:, ["hour", "distrito_departure", "distrito_arrival", "user_type_code"]]
tmp.columns = ['hora', 'distrito origen', 'distrito destino', 'Cantidad movimientos']
tmp[tmp.hora == 7].sort_values(by=["Cantidad movimientos"], ascending=False).head(50)

# %% [markdown]
# Visualizo tabla de movimientos por estacion

# %%
tmp = data.groupby(['hour','name_departure', 'name_arrival']).count().reset_index().loc[:, ["hour", "name_departure", "name_arrival", "user_type_code"]]
tmp.columns = ['hora', 'estacion origen', 'estacion destino', 'Cantidad movimientos']
tmp[tmp.hora == 7].sort_values(by=["Cantidad movimientos"], ascending=False).head(50)
