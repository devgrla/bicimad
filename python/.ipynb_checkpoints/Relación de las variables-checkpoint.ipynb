# %% [markdown]
# # Analisis Exploratorio - Relación Entre Variables
#
# Una vez finalizado el proceso de extracción y limpieza de los archivos de clima, calidad del aire, usos diarios de BiciMAD y accidentes, pasaremos a juntar la información con una periodicidad diaria para asi realizar un analisis exploratorio que nos permita llegar a conclusiones sobre la relación entre las variables y entender el efecto que puedan tener las variables independientes (clima, calidad del aire, accidentes) sobre la variable dependiente (uso de BiciMAD).

# %%
import pandas as pd
import numpy as np
from datetime import date, datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import psycopg2 as pg
from psycopg2 import sql

# %% [markdown]
# Cargamos los archivos de la base de datos y las cargamos en un DataFrame.

# %%
conn = pg.connect("postgres://xseed:LosTilos114@postgre-sqltest.cpdeokpzufj1.us-west-2.rds.amazonaws.com:5432/postgres")
weather = pd.read_sql('SELECT date, precipitation, temp_min, temp_media, temp_max, wind_speed, wind_speed_max FROM weather_conditions', conn)
conn.commit()
conn.close()

# %%
weather = weather.sort_values('date', ascending=True)
weather = weather.reset_index()
weather.drop(weather.columns[0], axis=1, inplace=True)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 7 columns):
# date              1859 non-null object
# precipitation     1859 non-null float64
# temp_max          1859 non-null float64
# temp_media        1859 non-null float64
# temp_min          1859 non-null float64
# wind_speed        1859 non-null float64
# wind_speed_max    1859 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 101.7+ KB

# %%
conn = pg.connect("postgres://xseed:LosTilos114@postgre-sqltest.cpdeokpzufj1.us-west-2.rds.amazonaws.com:5432/postgres")
accidents = pd.read_sql('SELECT date, age, victims, district FROM accidents', conn)
conn.commit()
conn.close()

# %%
accidents = accidents.sort_values('date', ascending=True)
accidents = accidents.reset_index()
accidents.drop(accidents.columns[0], axis=1, inplace=True)

# %%
accidents.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 4 columns):
# date        3660 non-null datetime64[ns]
# age         3660 non-null float64
# victims     3660 non-null int64
# district    3660 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 114.5+ KB

# %%
conn = pg.connect("postgres://xseed:LosTilos114@postgre-sqltest.cpdeokpzufj1.us-west-2.rds.amazonaws.com:5432/postgres")
air = pd.read_sql('SELECT date, ozono, dioxido_nitrogeno FROM air_quality', conn)
conn.commit()
conn.close()

# %%
air = air.sort_values('date', ascending=True)
air = air.reset_index()
air.drop(air.columns[0], axis=1, inplace=True)

# %%
air.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1823 entries, 0 to 1822
# Data columns (total 3 columns):
# date                 1823 non-null object
# ozono                1823 non-null float64
# dioxido_nitrogeno    1823 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 42.8+ KB

# %%
bicis_usos = pd.read_csv('../dat/bicis_usos_acumulado por dia.csv', sep=';')
bicis_usos.head()
# Out:
#           DIA  Usos bicis abono anual   Usos bicis abono ocasional   \
# 0  23/06/2014                       17                           79
# 1  24/06/2014                       24                           48
# 2  25/06/2014                      105                           14
# 3  26/06/2014                      120                           15
# 4  27/06/2014                      131                           18
#
#    Usos bicis total  Usos abono anual acumulado  \
# 0                96                          17
# 1                72                          41
# 2               119                         146
# 3               135                         266
# 4               149                         397
#
#    Usos abono ocasional acumulado  Usos total acumulado desde inicio  \
# 0                              79                                 96
# 1                             127                                168
# 2                             141                                287
# 3                             156                                422
# 4                             174                                571
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# Convertimos la tabla de accidentes a serie de tiempo para juntar los datos a una periodicidad diaria.

# %%
accT = accidents.set_index(accidents.date)
acc_dia = accT.resample('D').count()

# %%
acc_dia['date1'] = acc_dia.index
acc_dia['date1'] = [str(i) for i in acc_dia.date1]
acc_dia.drop(acc_dia.columns[0:3], axis=1, inplace=True)
acc_dia.columns = ['accidents', 'date']
acc_dia.date = acc_dia.date.str[0:10]

# %%
acc_dia.head()
# Out:
#             accidents        date
# date
# 2014-01-08          1  2014-01-08
# 2014-01-09          2  2014-01-09
# 2014-01-10          0  2014-01-10
# 2014-01-11          1  2014-01-11
# 2014-01-12          0  2014-01-12

# %%
import math
def remove_Nan(element):
    if math.isnan(element):
        return accT.edad.median()
    else:
        return element
    
accT['edad'] = accT.edad.apply(remove_Nan)

# %%
acc_m = accT.resample('D').median()
acc_m['date1'] = acc_m.index
acc_m['date1'] = [str(i) for i in acc_m.date1]
acc_m.date1 = acc_m.date1.str[0:10]
acc_m.drop(acc_m.columns[1], axis=1, inplace=True)
acc_m.columns = ['age_acc', 'date']

# %%
acc_m.head()
# Out:
#             age_acc        date
# date
# 2014-01-08     19.0  2014-01-08
# 2014-01-09     39.5  2014-01-09
# 2014-01-10      NaN  2014-01-10
# 2014-01-11     27.0  2014-01-11
# 2014-01-12      NaN  2014-01-12

# %%
acc_v = accT.resample('D').sum()
acc_v['date1'] = acc_v.index
acc_v['date1'] = [str(i) for i in acc_v.date1]
acc_v.date1 = acc_v.date1.str[0:10]
acc_v.drop(acc_v.columns[0], axis=1, inplace=True)
acc_v.columns = ['victims', 'date']

# %%
acc_v.head()
# Out:
#             victims        date
# date
# 2014-01-08        1  2014-01-08
# 2014-01-09        2  2014-01-09
# 2014-01-10        0  2014-01-10
# 2014-01-11        1  2014-01-11
# 2014-01-12        0  2014-01-12

# %% [markdown]
# Una vez teniendo todas las tablas transformadas podemos realizar un merge para juntar las variables de usos de BiciMAd, clima y contaminación.

# %%
acc_daily = acc_v.merge(acc_dia)
# Out:
# C:\Users\alejo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
acc_daily = acc_daily.merge(acc_m)
# Out:
# C:\Users\alejo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
acc_daily.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1817 entries, 0 to 1816
# Data columns (total 4 columns):
# date         1817 non-null object
# age_acc      1516 non-null float64
# victims      1817 non-null int64
# accidents    1817 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 71.0+ KB

# %%
bicis_usos.drop(bicis_usos.columns[3:], axis=1, inplace=True)
bicis_usos.head()
# Out:
#         date  annual_user  occasional_user
# 0 2014-06-23           17               79
# 1 2014-06-24           24               48
# 2 2014-06-25          105               14
# 3 2014-06-26          120               15
# 4 2014-06-27          131               18

# %%
bicis_usos.columns = ['date', 'annual_user', 'occasional_user']

# %%
def cast_date(date):
    return datetime.strptime(date, '%d/%m/%Y')

bicis_usos['date'] = bicis_usos.date.apply(cast_date)
bicis_usos['date'] = [str(i) for i in bicis_usos.date]
bicis_usos.date = bicis_usos.date.str[0:10]

# %%
bicis_usos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 3 columns):
# date               1653 non-null object
# annual_user        1653 non-null int64
# occasional_user    1653 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 38.8+ KB

# %%
bicimad = bicis_usos.merge(acc_daily)

# %%
bicimad3.head()
# Out:
#          date  annual_user  occasional_user  age_acc  victims  accidents  \
# 0  2014-06-23           17               79     32.0        2          1
# 1  2014-06-24           24               48      NaN        0          0
# 2  2014-06-25          105               14     36.5        2          2
# 3  2014-06-26          120               15     29.5        4          4
# 4  2014-06-27          131               18     37.0        3          3
#
#    precipitation  temp_max  temp_media  temp_min  wind_speed  wind_speed_max  \
# 0            0.0      29.7        23.2      16.6         1.7             9.2
# 1            0.0      19.8        18.4      17.0         1.7             8.9
# 2            1.7      27.0        21.6      16.2         1.4             5.8
# 3            0.4      26.2        20.8      15.5         0.6             5.8
# 4            0.0      30.4        23.7      17.0         2.2            10.0
#
#    ozono  dioxido_nitrogeno
# 0   59.0               20.0
# 1   61.0               17.0
# 2   74.0               20.0
# 3   65.0               21.0
# 4   60.0               23.0

# %%
weather['date'] = [str(i) for i in weather.date]

# %%
bicimad2 = bicimad.merge(weather)

# %%
air['date'] = [str(i) for i in air.date]

# %%
bicimad3 = bicimad2.merge(air)

# %% [markdown]
# Exportamos la tabla a CSV.

# %%
bicimad3.to_csv('../dat/merge_variables.csv')

# %%
merged = pd.read_csv('../dat/merge_variables.csv', index_col=0)
merged.head()
# Out:
#          date  annual_user  occasional_user  age_acc  victims  accidents  \
# 0  2014-06-23           17               79     32.0        2          1
# 1  2014-06-24           24               48      NaN        0          0
# 2  2014-06-25          105               14     36.5        2          2
# 3  2014-06-26          120               15     29.5        4          4
# 4  2014-06-27          131               18     37.0        3          3
#
#    precipitation  temp_max  temp_media  temp_min  wind_speed  wind_speed_max  \
# 0            0.0      29.7        23.2      16.6         1.7             9.2
# 1            0.0      19.8        18.4      17.0         1.7             8.9
# 2            1.7      27.0        21.6      16.2         1.4             5.8
# 3            0.4      26.2        20.8      15.5         0.6             5.8
# 4            0.0      30.4        23.7      17.0         2.2            10.0
#
#    ozono  dioxido_nitrogeno
# 0   59.0               20.0
# 1   61.0               17.0
# 2   74.0               20.0
# 3   65.0               21.0
# 4   60.0               23.0

# %%
def cast_date(date):
    return datetime.strptime(date, '%Y-%m-%d')

merged['date'] = merged.date.apply(cast_date)
mergedT = merged.set_index(merged.date)

# %%
mergedT['month'] = mergedT.apply(lambda fila: fila.date.month, axis=1)
mergedT['year'] = mergedT.apply(lambda fila: fila.date.year, axis=1)
mergedT['weekday'] = mergedT.apply(lambda fila: fila.date.weekday(), axis=1)

# %%
mergedT.head()
# Out:
#                  date  annual_user  occasional_user  age_acc  victims  \
# date
# 2014-06-23 2014-06-23           17               79     32.0        2
# 2014-06-24 2014-06-24           24               48      NaN        0
# 2014-06-25 2014-06-25          105               14     36.5        2
# 2014-06-26 2014-06-26          120               15     29.5        4
# 2014-06-27 2014-06-27          131               18     37.0        3
#
#             accidents  precipitation  temp_max  temp_media  temp_min  \
# date
# 2014-06-23          1            0.0      29.7        23.2      16.6
# 2014-06-24          0            0.0      19.8        18.4      17.0
# 2014-06-25          2            1.7      27.0        21.6      16.2
# 2014-06-26          4            0.4      26.2        20.8      15.5
# 2014-06-27          3            0.0      30.4        23.7      17.0
#
#             wind_speed  wind_speed_max  ozono  dioxido_nitrogeno  month  year  \
# date
# 2014-06-23         1.7             9.2   59.0               20.0      6  2014
# 2014-06-24         1.7             8.9   61.0               17.0      6  2014
# 2014-06-25         1.4             5.8   74.0               20.0      6  2014
# 2014-06-26         0.6             5.8   65.0               21.0      6  2014
# 2014-06-27         2.2            10.0   60.0               23.0      6  2014
#
#             weekday
# date
# 2014-06-23        0
# 2014-06-24        1
# 2014-06-25        2
# 2014-06-26        3
# 2014-06-27        4

# %%
mergedT['2016-01':'2016-2']
# Out:
#                  date  annual_user  occasional_user  age_acc  victims  \
# date
# 2016-01-01 2016-01-01         3369              289      NaN        0
# 2016-01-02 2016-01-02         4738              298    12.00        1
# 2016-01-03 2016-01-03         3919              153    42.00        3
# 2016-01-04 2016-01-04         4219               95      NaN        0
# 2016-01-05 2016-01-05         6712              144    37.00        1
# 2016-01-06 2016-01-06         3574               79    57.00        1
# 2016-01-07 2016-01-07         6643               84      NaN        0
# 2016-01-08 2016-01-08         6621               89    42.00        3
# 2016-01-09 2016-01-09         6132              126      NaN        0
# 2016-01-10 2016-01-10         3233               40      NaN        0
# 2016-01-12 2016-01-12         7710               52    42.00        1
# 2016-01-13 2016-01-13         8069               58    37.00        1
# 2016-01-14 2016-01-14         5378               23    23.00        2
# 2016-01-15 2016-01-15         8043               41    19.00        4
# 2016-01-16 2016-01-16         7218              224    32.00        3
# 2016-01-17 2016-01-17         5755              161    32.00        5
# 2016-01-18 2016-01-18         7002               51    29.75        2
# 2016-01-19 2016-01-19         7669               44    27.00        5
# 2016-01-20 2016-01-20         7881               47      NaN        0
# 2016-01-21 2016-01-21         7960               42    57.00        1
# 2016-01-22 2016-01-22         7674               54    42.00        4
# 2016-01-23 2016-01-23         8214              327    12.00        1
# 2016-01-24 2016-01-24         8189              401    18.50        2
# 2016-01-25 2016-01-25         8115              100    27.00        5
# 2016-01-26 2016-01-26         8852              103    27.00        4
# 2016-01-27 2016-01-27         8284               65    27.00        4
# 2016-01-28 2016-01-28         6189               31    37.00        3
# 2016-01-29 2016-01-29         7609               52    16.00        1
# 2016-01-30 2016-01-30         7832              233    24.75        4
# 2016-01-31 2016-01-31         7424              402    27.00        5
# 2016-02-01 2016-02-01         8451              139    47.00        1
# 2016-02-02 2016-02-02         8741              115    27.25        2
# 2016-02-03 2016-02-03         9214               68    37.00        2
# 2016-02-04 2016-02-04         8992               53    27.00        1
# 2016-02-05 2016-02-05         9145               95    22.50        1
# 2016-02-06 2016-02-06         6781              202    16.00        1
# 2016-02-07 2016-02-07         5337              209    52.00        1
# 2016-02-08 2016-02-08         7387               73    57.00        1
# 2016-02-09 2016-02-09         7429               63    11.25        2
# 2016-02-10 2016-02-10         8634               38    42.00        1
# 2016-02-11 2016-02-11         7491               24    42.00        2
# 2016-02-12 2016-02-12         5129               30    16.00        1
# 2016-02-13 2016-02-13         5180              133    27.00        1
# 2016-02-14 2016-02-14         4131               88      NaN        0
# 2016-02-15 2016-02-15         6740               49      NaN        0
# 2016-02-16 2016-02-16         7308               46    27.00        3
# 2016-02-17 2016-02-17         7468               39    67.00        1
# 2016-02-18 2016-02-18         6715               24    37.00        2
# 2016-02-19 2016-02-19         8267              120    39.50        2
# 2016-02-20 2016-02-20         7314              325     0.00        1
# 2016-02-21 2016-02-21         6678              298    25.50        2
# 2016-02-22 2016-02-22         7883               98    32.00        1
# 2016-02-23 2016-02-23         8821              108    47.00        1
# 2016-02-24 2016-02-24         6959               34    32.00        1
# 2016-02-25 2016-02-25         8496               89    32.00        1
# 2016-02-26 2016-02-26         4576               22    22.50        1
# 2016-02-27 2016-02-27         5636              147      NaN        0
# 2016-02-28 2016-02-28         5276              122    47.00        5
# 2016-02-29 2016-02-29         7716              132    32.00        1
#
#             accidents  precipitation  temp_max  temp_media  temp_min  \
# date
# 2016-01-01          0            3.2      14.4        11.3       8.2
# 2016-01-02          1            0.0      11.4         8.2       5.0
# 2016-01-03          2            0.4      11.9         8.3       4.7
# 2016-01-04          0            4.1      13.5        10.2       6.8
# 2016-01-05          1            0.0       9.6         6.8       4.1
# 2016-01-06          1            0.3       8.9         5.2       1.4
# 2016-01-07          0            0.5      14.4        11.6       8.9
# 2016-01-08          3            6.0      12.9        11.6      10.4
# 2016-01-09          0            0.2      11.5         9.8       8.2
# 2016-01-10          0           12.0      12.0        10.2       8.5
# 2016-01-12          1            0.0      10.6         6.8       3.1
# 2016-01-13          1            0.0       9.6         5.8       2.0
# 2016-01-14          2            2.1       8.6         6.2       3.8
# 2016-01-15          3            0.0       9.6         6.8       4.0
# 2016-01-16          3            0.0       8.3         4.4       0.6
# 2016-01-17          5            0.0       7.0         3.0      -0.9
# 2016-01-18          2            0.0       9.8         6.0       2.2
# 2016-01-19          3            0.0       8.8         5.8       2.7
# 2016-01-20          0            0.0       9.2         5.4       1.6
# 2016-01-21          1            0.0       9.0         6.8       4.6
# 2016-01-22          3            0.8      11.3         8.6       6.0
# 2016-01-23          1            0.0      16.2        12.2       8.2
# 2016-01-24          2            0.0      17.5        12.8       8.2
# 2016-01-25          4            0.0      16.4        12.2       8.0
# 2016-01-26          3            0.0      14.4        10.7       7.0
# 2016-01-27          4            0.0      10.1         8.6       7.0
# 2016-01-28          3            3.7       9.6         8.5       7.4
# 2016-01-29          1            0.5      10.6         8.6       6.5
# 2016-01-30          4            0.0      12.9         8.6       4.2
# 2016-01-31          5            0.0      14.8        10.9       7.0
# 2016-02-01          1            0.0      15.4        10.4       5.3
# 2016-02-02          2            0.0      14.2        10.0       5.8
# 2016-02-03          2            0.0      14.4        10.0       5.7
# 2016-02-04          1            0.0      11.2         7.4       3.5
# 2016-02-05          1            0.0      10.7         7.0       3.2
# 2016-02-06          1           13.8      11.5         7.0       2.5
# 2016-02-07          1            0.0      10.6         7.2       3.9
# 2016-02-08          1            0.0      12.2         8.8       5.5
# 2016-02-09          2            0.6      12.6        10.6       8.6
# 2016-02-10          1            0.0      14.3        11.4       8.5
# 2016-02-11          2            2.8      16.2        13.4      10.5
# 2016-02-12          1            6.2      13.5        11.2       8.8
# 2016-02-13          1            2.3      13.8        12.7      11.6
# 2016-02-14          0            2.4      12.0         8.2       4.4
# 2016-02-15          0            0.0      10.5         6.8       3.0
# 2016-02-16          3            0.0       8.5         4.6       0.7
# 2016-02-17          1            2.2       8.6         3.0      -2.5
# 2016-02-18          2            1.7      10.2         6.8       3.4
# 2016-02-19          2            0.0      11.0         6.2       1.5
# 2016-02-20          1            0.0      13.5         7.8       2.2
# 2016-02-21          2            0.0      13.7         9.0       4.2
# 2016-02-22          1            0.0      15.2        10.1       5.0
# 2016-02-23          1            0.0      15.0        10.0       4.9
# 2016-02-24          1            1.5      10.7         7.4       4.2
# 2016-02-25          1            0.0      13.0         8.7       4.4
# 2016-02-26          1            5.8       8.2         5.8       3.3
# 2016-02-27          0            0.0       8.2         5.4       2.6
# 2016-02-28          3            0.0      11.7         7.7       3.7
# 2016-02-29          1            0.0      13.4         8.2       2.9
#
#             wind_speed  wind_speed_max  ozono  dioxido_nitrogeno  month  year
# date
# 2016-01-01         1.9             8.9   23.0               31.0      1  2016
# 2016-01-02         1.9             9.2   44.0               21.0      1  2016
# 2016-01-03         2.5            10.3   27.0               30.0      1  2016
# 2016-01-04         6.4            23.3   29.0               20.0      1  2016
# 2016-01-05         3.1            11.9   55.0               21.0      1  2016
# 2016-01-06         2.2            14.2   43.0               20.0      1  2016
# 2016-01-07         4.4            13.9   38.0               18.0      1  2016
# 2016-01-08         1.9            11.7   38.0               26.0      1  2016
# 2016-01-09         2.5            12.8   52.0               24.0      1  2016
# 2016-01-10         3.9            17.2   61.0               13.0      1  2016
# 2016-01-12         1.4             6.9   33.0               43.0      1  2016
# 2016-01-13         0.6             3.9    9.0               57.0      1  2016
# 2016-01-14         0.6             5.3    9.0               56.0      1  2016
# 2016-01-15         2.2            11.9   36.0               37.0      1  2016
# 2016-01-16         1.9            10.3   46.0               33.0      1  2016
# 2016-01-17         0.6             5.3   15.0               57.0      1  2016
# 2016-01-18         2.8             9.2   31.0               41.0      1  2016
# 2016-01-19         1.1             5.8   35.0               46.0      1  2016
# 2016-01-20         0.3             4.2   15.0               57.0      1  2016
# 2016-01-21         0.3             3.3   14.0               52.0      1  2016
# 2016-01-22         1.1             4.7    7.0               62.0      1  2016
# 2016-01-23         1.1             5.0   13.0               45.0      1  2016
# 2016-01-24         0.6             4.7   20.0               38.0      1  2016
# 2016-01-25         0.8             4.7   11.0               57.0      1  2016
# 2016-01-26         0.8             5.6   12.0               48.0      1  2016
# 2016-01-27         0.6             3.9   10.0               51.0      1  2016
# 2016-01-28         1.1             5.8   21.0               47.0      1  2016
# 2016-01-29         1.9             7.8   29.0               50.0      1  2016
# 2016-01-30         1.1             6.9   32.0               35.0      1  2016
# 2016-01-31         0.3             8.1   35.0               39.0      1  2016
# 2016-02-01         0.6             4.7    9.0               60.0      2  2016
# 2016-02-02         0.3             5.0    8.0               60.0      2  2016
# 2016-02-03         2.8            10.8   42.0               34.0      2  2016
# 2016-02-04         1.4             8.9   46.0               37.0      2  2016
# 2016-02-05         0.8             6.1   24.0               51.0      2  2016
# 2016-02-06         1.4            13.3   19.0               45.0      2  2016
# 2016-02-07         1.7            14.7   59.0               17.0      2  2016
# 2016-02-08         2.5             9.4   42.0               25.0      2  2016
# 2016-02-09         4.7            18.6   50.0               16.0      2  2016
# 2016-02-10         4.4            15.6   45.0               17.0      2  2016
# 2016-02-11         2.8            13.9   43.0               20.0      2  2016
# 2016-02-12         4.2            16.1   36.0               19.0      2  2016
# 2016-02-13         4.4            15.3   32.0               12.0      2  2016
# 2016-02-14         3.6            17.8   63.0               13.0      2  2016
# 2016-02-15         4.2            17.5   62.0               21.0      2  2016
# 2016-02-16         3.6            14.7   58.0               24.0      2  2016
# 2016-02-17         1.4             9.7   37.0               42.0      2  2016
# 2016-02-18         1.4             8.9   42.0               34.0      2  2016
# 2016-02-19         2.5             9.2   46.0               35.0      2  2016
# 2016-02-20         1.4             6.7   42.0               41.0      2  2016
# 2016-02-21         1.4             6.4   40.0               35.0      2  2016
# 2016-02-22         1.1             6.7   33.0               46.0      2  2016
# 2016-02-23         1.7             6.4   33.0               45.0      2  2016
# 2016-02-24         2.2             9.2   22.0               44.0      2  2016
# 2016-02-25         2.5            11.7   49.0               26.0      2  2016
# 2016-02-26         1.9            13.6   40.0               30.0      2  2016
# 2016-02-27         4.2            17.8   66.0               12.0      2  2016
# 2016-02-28         3.3             0.0   54.0               19.0      2  2016
# 2016-02-29         1.9            11.7   57.0               33.0      2  2016

# %% [markdown]
# ## Visualización
#
# Empezamos la visualización exploratoria para determinar si existe una correlación entre las variables.

# %%
from matplotlib import rcParams
import matplotlib
# %matplotlib inline
rcParams['figure.figsize'] = 14, 10
sns.set_context('talk')
sns.set_style("darkgrid")

# %%
out = sns.scatterplot(x='temp_media', y='annual_user', data=merged)

# %%
merged14 = mergedT[mergedT['year']==2014]
merged15 = mergedT[mergedT['year']==2015]
merged16 = mergedT[mergedT['year']==2016]
merged17 = mergedT[mergedT['year']==2017]
merged18 = mergedT[mergedT['year']==2018]

# %%
cmap = sns.palplot(sns.cubehelix_palette(8, start=2, rot=0, dark=0, light=.95))
cmap1 = sns.cubehelix_palette(light=1, as_cmap=True)
p = sns.palplot(sns.color_palette("ch:2.5,-.2,dark=.3"))

# %%
cmap1 = sns.palplot(sns.light_palette("navy", reverse=True))

# %%
out = sns.scatterplot(x='temp_media', y='annual_user', size = 'precipitation', data=merged18)

# %%
out = sns.pairplot(merged18)
# Out:
# C:\Users\alejo\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\alejo\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
out = sns.scatterplot(x='wind_speed', y='annual_user', size = 'precipitation', data=merged18)
